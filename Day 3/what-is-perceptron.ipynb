# %% [markdown]
# > #### 1) Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# > #### 2) Reading file

# %%
df = pd.read_csv('placement.csv')

# %% [markdown]
# - Checking shape of data

# %%
df.shape
# Out:
# (100, 3)

# %% [markdown]
# - Checking first 5 rows od data

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %% [markdown]
# - creating plot to see data distribution

# %%
plt.figure(figsize=(8,3))
sns.scatterplot(x=df['cgpa'],y=df['resume_score'],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
perceptron = Perceptron()

# %%
perceptron.fit(X,y)
# Out:
# Perceptron()

# %%
perceptron.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
perceptron.intercept_
# Out:
# array([-25.])

# %%
plot_decision_regions(X.values, y.values, clf=perceptron, legend=2)
# Out:
# f:\Data Science\CampusX\100 Days of Deep Learning\dl-env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# > We have just use the `Perceptron` class of `sklearn.linear_model`:
# > - To see how a perceptron used to create a descision boundary/region i.e a line in 2D data between the classes

# %% [markdown]
# ## Done!
